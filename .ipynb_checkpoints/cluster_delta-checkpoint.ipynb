# %%
import pandas as pd
path = './d100.csv'

# %time df = pd.read_csv(path)
# Out:
# CPU times: user 2.99 ms, sys: 1.1 ms, total: 4.09 ms
# Wall time: 3.21 ms

# %%
#remove the children that dont make any money, and the deadbeat milleinals 
df2 = df[(df.INCTOT < 9999999) & (df.INCTOT != 0)]

# %%
df2
# Out:
#     STATEFIP  CITY  SEX  AGE  INCTOT
# 0         17     0    1   54   63000
# 1         51   310    1   40  140000
# 3         55     0    2   63   15200
# 4         31     0    1   40   31200
# 5         42     0    2   28   22000
# 6         33     0    1   53   20800
# 8         39     0    1   21   17000
# 10        48     0    2   61   38400
# 12        36     0    1   32   20000
# 14        34     0    2   34    4500
# 15        48     0    2   35   19200
# 16        18     0    1   69   48600
# 17        24     0    2   68   39900
# 18        26     0    2   69   12800
# 19         9     0    2   64   37700
# 20        39     0    2   52   72000
# 22        12     0    2   58   90000
# 23        36     0    1   35  190000
# 25         6     0    2   27   60000
# 26        28     0    1   30   38000
# 28         6     0    2   26   40000
# 30        37     0    1   62   15000
# 31        39     0    2   49   35000
# 32         6     0    2   66    7000
# ...
